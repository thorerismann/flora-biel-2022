# %%
# import packages

# math and data packages
import pandas as pd
import numpy as np
import math

# charting and graphics
import matplotlib as mpl
import matplotlib.pyplot as plt
# from matplotlib import colors
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
from matplotlib.gridspec import GridSpec
import matplotlib.image as mpimg

# os and file types
import os
import sys
import datetime as dt
import json
import csv

# %%
# import data

first = pd.read_csv("data/obs_export_2022-04-17_23h22.csv",encoding = "utf-16",sep = "\t")
second = pd.read_csv("data/obs_export_2022-04-17_23h23.csv",encoding = "utf-16",sep = "\t")
poac = pd.read_csv("data/poacea-for-maps.csv",encoding = "utf-16",sep = "\t")

# initial dataset transformations

# concatonate the different datasets of observations
all_data = pd.concat([first,second],ignore_index = True)

# transform pd object into dt object for date column
all_data["md"] = pd.to_datetime(all_data['date'], errors='coerce', format='%Y-%m-%d')
all_data["month"] = all_data["md"].dt.month
all_data["year"] = all_data["md"].dt.year

# check data / column names

# for i in all_data.columns:
#    print(F"column {i} ++ value {all_data.at[0,i]}")
# all_data.columns

# %%
# export data for use with google maps to guide ongoing surveys

poa = all_data[all_data.taxon_orig == "Poaceae"]
poa_simp = poac[["taxon_orig","x","y","locality_descript","obs_id","date"]]
hed = all_data[all_data.taxon_orig == "Hedera helix"]
poa_simp.to_csv("output/only-poa.csv", sep = ",")

# %%
# initial exploration of data

# note some mislabeled names
# list must also be backdated with past names
# 2022 places are the keys, that is, they are taken to be the most correct
# most place name work needs to take place on mapping software
# hed.locality_descript.unique()
